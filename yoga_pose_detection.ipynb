# %% [markdown]
# ## Yoga Pose Detection

# %% [markdown]
# Shiva and Rishi
# mini project

# %% [markdown]
# ### Import important libraries

# %%
# pip install mediapipe

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# %%
# !pip install opencv-contrib-python
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.3.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # taking a sample image input

# %%
img = cv2.imread("./treepose1.jpg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=[5, 5])
plt.imshow(img)

# %% [markdown]
# # understanding the pose of the image

# %% [markdown]
# initialize the pose class

# %%
mp_pose = mp.solutions.pose

# %% [markdown]
# call the Pose function

# %%
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)

# %% [markdown]
# analyse the image, store the outcome in a variable

# %%
results = pose.process(img)

# %% [markdown]
# # This "results" variable contains all the major points of body for pose detection

# %% [markdown]
# it contains the normalized coordinate points  between 0 and 1

# %%
if results.pose_landmarks:
        for i in range(11, 15):
            print(f'{mp_pose.PoseLandmark(i).name}:\n{results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value]}')
# Out:
# LEFT_SHOULDER:
# x: 0.676351
# y: 0.35830888
# z: -0.006474229
# visibility: 0.9990741
#
# RIGHT_SHOULDER:
# x: 0.43686727
# y: 0.3643506
# z: 0.13494763
# visibility: 0.9981225
#
# LEFT_ELBOW:
# x: 0.7184681
# y: 0.46378928
# z: -0.24630201
# visibility: 0.9819725
#
# RIGHT_ELBOW:
# x: 0.3847292
# y: 0.46506032
# z: -0.11359997
# visibility: 0.97482353

# %% [markdown]
# # fetching the landmark points in terms of x,y,z pixel coordinates

# %%
image_height, image_http://localhost:8888/notebooks/Documents/Mtech/SEM_2/Computer_Vision/yoga%20pose/yoga_pose_detection.ipynb#fetching-the-landmark-points-in-terms-of-x,y,z-pixel-coordinateswidth, _ = img.shape

print(image_height)
print(image_width)
# Out:
# 1280
# 853

# %%
if results.pose_landmarks:
    for i in range(27, 32):
        print(f'{mp_pose.PoseLandmark(i).name}:') 
        print(f'x: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].x * image_width}')
        print(f'y: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].y * image_height}')
        print(f'z: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].z * image_width}')
        print(f'visibility: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].visibility}\n')
# Out:
# LEFT_ANKLE:
# x: 459.49893540143967
# y: 1164.4441223144531
# z: 94.45908334106207
# visibility: 0.9612603783607483
#
# RIGHT_ANKLE:
# x: 429.92176872491837
# y: 852.3713684082031
# z: 257.87037056684494
# visibility: 0.7241400480270386
#
# LEFT_HEEL:
# x: 453.7865985631943
# y: 1184.65087890625
# z: 112.23829513788223
# visibility: 0.7583548426628113
#
# RIGHT_HEEL:
# x: 454.243674993515
# y: 832.7295684814453
# z: 308.38995054364204
# visibility: 0.7104861736297607
#
# LEFT_FOOT_INDEX:
# x: 449.8635710477829
# y: 1241.4308166503906
# z: -58.16139327734709
# visibility: 0.9066981673240662

# %% [markdown]
# # drawing the landmarks

# %%
mp_drawing = mp.solutions.drawing_utils

# %%
img_copy = img.copy()

# Check if any landmarks are found.
if results.pose_landmarks:
    
    # Draw Pose landmarks on the sample image.
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)
       
    # Specify a size of the figure.
    fig = plt.figure(figsize = [8, 8])

    # Display the output image with the landmarks drawn, also convert BGR to RGB for display. 
    plt.title("Output");
    plt.axis('off');
    plt.imshow(img_copy);
    plt.show();

# %% [markdown]
# # understanding the landmark distance into meters(in 3D)

# %% [markdown]
# the visualization cube shows the landmark point from a front left perpective

# %%
mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)

# %% [markdown]
# with the 3D image we can clearly say that the right knee is clearly infront from other body parts

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt
img = cv2.imread("./treepose1.jpg")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=[5, 5])
plt.imshow(img)
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)
results = pose.process(img)
if results.pose_landmarks:
        for i in range(11, 15):
            print(f'{mp_pose.PoseLandmark(i).name}:\n{results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value]}') 
image_height, image_width, _ = img.shape

print(image_height)
print(image_width)
if results.pose_landmarks:
    for i in range(27, 32):
        print(f'{mp_pose.PoseLandmark(i).name}:') 
        print(f'x: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].x * image_width}')
        print(f'y: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].y * image_height}')
        print(f'z: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].z * image_width}')
        print(f'visibility: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].visibility}\n')

mp_drawing = mp.solutions.drawing_utils
img_copy = img.copy()

# Check if any landmarks are found.
if results.pose_landmarks:
    
    # Draw Pose landmarks on the sample image.
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)
       
    # Specify a size of the figure.
    fig = plt.figure(figsize = [8, 8])

    # Display the output image with the landmarks drawn, also convert BGR to RGB for display. 
    plt.title("Output");
    plt.axis('off');
    plt.imshow(img_copy);
    plt.show();

mp_drawing.plot_landmarks(results.pose_world_landmarks, mp_pose.POSE_CONNECTIONS)
# Out:
# LEFT_SHOULDER:
# x: 0.676351
# y: 0.35830888
# z: -0.006474229
# visibility: 0.9990741
#
# RIGHT_SHOULDER:
# x: 0.43686727
# y: 0.3643506
# z: 0.13494763
# visibility: 0.9981225
#
# LEFT_ELBOW:
# x: 0.7184681
# y: 0.46378928
# z: -0.24630201
# visibility: 0.9819725
#
# RIGHT_ELBOW:
# x: 0.3847292
# y: 0.46506032
# z: -0.11359997
# visibility: 0.97482353
#
# 1280
# 853
# LEFT_ANKLE:
# x: 459.49893540143967
# y: 1164.4441223144531
# z: 94.45908334106207
# visibility: 0.9612603783607483
#
# RIGHT_ANKLE:
# x: 429.92176872491837
# y: 852.3713684082031
# z: 257.87037056684494
# visibility: 0.7241400480270386
#
# LEFT_HEEL:
# x: 453.7865985631943
# y: 1184.65087890625
# z: 112.23829513788223
# visibility: 0.7583548426628113
#
# RIGHT_HEEL:
# x: 454.243674993515
# y: 832.7295684814453
# z: 308.38995054364204
# visibility: 0.7104861736297607
#
# LEFT_FOOT_INDEX:
# x: 449.8635710477829
# y: 1241.4308166503906
# z: -58.16139327734709
# visibility: 0.9066981673240662

# %%
import cv2
import mediapipe as mp
import matplotlib.pyplot as plt

# Load image
img = cv2.imread("./treepose1.jpg")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the original image
plt.figure(figsize=[5, 5])
plt.imshow(img)
plt.title("Original Image")
plt.axis('off')
plt.show()

# Run Mediapipe pose detection
mp_pose = mp.solutions.pose
pose = mp_pose.Pose(static_image_mode=True, min_detection_confidence=0.5)
results = pose.process(img)

# Extract relevant information
if results.pose_landmarks:
    for i in range(11, 15):
        print(f'{mp_pose.PoseLandmark(i).name}:\n{results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value]}') 

image_height, image_width, _ = img.shape
print(image_height)
print(image_width)

if results.pose_landmarks:
    for i in range(27, 32):
        print(f'{mp_pose.PoseLandmark(i).name}:') 
        print(f'x: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].x * image_width}')
        print(f'y: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].y * image_height}')
        print(f'z: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].z * image_width}')
        print(f'visibility: {results.pose_landmarks.landmark[mp_pose.PoseLandmark(i).value].visibility}\n')

# Plot landmarks on the image
mp_drawing = mp.solutions.drawing_utils
img_copy = img.copy()

if results.pose_landmarks:
    mp_drawing.draw_landmarks(image=img_copy, landmark_list=results.pose_landmarks, connections=mp_pose.POSE_CONNECTIONS)
    plt.figure(figsize=[8, 8])
    plt.imshow(img_copy)
    plt.title("Output with Pose Landmarks")
    plt.axis('off')
    plt.show()

# You can save these plots as images using plt.savefig("filename.png")
# Then manually create a PowerPoint presentation and insert these images into slides.
# Out:
# LEFT_SHOULDER:
# x: 0.676351
# y: 0.35830888
# z: -0.006474229
# visibility: 0.9990741
#
# RIGHT_SHOULDER:
# x: 0.43686727
# y: 0.3643506
# z: 0.13494763
# visibility: 0.9981225
#
# LEFT_ELBOW:
# x: 0.7184681
# y: 0.46378928
# z: -0.24630201
# visibility: 0.9819725
#
# RIGHT_ELBOW:
# x: 0.3847292
# y: 0.46506032
# z: -0.11359997
# visibility: 0.97482353
#
# 1280
# 853
# LEFT_ANKLE:
# x: 459.49893540143967
# y: 1164.4441223144531
# z: 94.45908334106207
# visibility: 0.9612603783607483
#
# RIGHT_ANKLE:
# x: 429.92176872491837
# y: 852.3713684082031
# z: 257.87037056684494
# visibility: 0.7241400480270386
#
# LEFT_HEEL:
# x: 453.7865985631943
# y: 1184.65087890625
# z: 112.23829513788223
# visibility: 0.7583548426628113
#
# RIGHT_HEEL:
# x: 454.243674993515
# y: 832.7295684814453
# z: 308.38995054364204
# visibility: 0.7104861736297607
#
# LEFT_FOOT_INDEX:
# x: 449.8635710477829
# y: 1241.4308166503906
# z: -58.16139327734709
# visibility: 0.9066981673240662
